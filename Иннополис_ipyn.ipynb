# %% [markdown]
# <a href="https://colab.research.google.com/github/MarinaKrasovskaia/1/blob/main/%D0%98%D0%BD%D0%BD%D0%BE%D0%BF%D0%BE%D0%BB%D0%B8%D1%81_ipyn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dt=pd.read_csv('GlobalWeatherRepository.csv')
pd.set_option('display.max_columns', None)
dt
# Out:
#          country     location_name  latitude  longitude         timezone  \
# 0    Afghanistan             Kabul     34.52      69.18       Asia/Kabul
# 1        Albania            Tirana     41.33      19.82    Europe/Tirane
# 2        Algeria           Algiers     36.76       3.05   Africa/Algiers
# 3        Andorra  Andorra La Vella     42.50       1.52   Europe/Andorra
# 4         Angola            Luanda     -8.84      13.23    Africa/Luanda
# ..           ...               ...       ...        ...              ...
# 580    Venezuela           Caracas     10.50     -66.92  America/Caracas
# 581      Vietnam             Hanoi     21.03     105.85     Asia/Bangkok
# 582        Yemen             Sanaa     15.35      44.21        Asia/Aden
# 583       Zambia            Lusaka    -15.42      28.28    Africa/Lusaka
# 584     Zimbabwe            Harare    -17.82      31.04    Africa/Harare
#
#      last_updated_epoch      last_updated  temperature_celsius  \
# ...

# %%
dt.isnull().loc[dt['latitude']==True]
# Out:
# Empty DataFrame
# Columns: [country, location_name, latitude, longitude, timezone, last_updated_epoch, last_updated, temperature_celsius, temperature_fahrenheit, condition_text, wind_mph, wind_kph, wind_degree, wind_direction, pressure_mb, pressure_in, precip_mm, precip_in, humidity, cloud, feels_like_celsius, feels_like_fahrenheit, visibility_km, visibility_miles, uv_index, gust_mph, gust_kph, air_quality_Carbon_Monoxide, air_quality_Ozone, air_quality_Nitrogen_dioxide, air_quality_Sulphur_dioxide, air_quality_PM2.5, air_quality_PM10, air_quality_us-epa-index, air_quality_gb-defra-index, sunrise, sunset, moonrise, moonset, moon_phase, moon_illumination]
# Index: []
#
# [0 rows x 41 columns]

# %%
dt_new = dt[dt['temperature_celsius'] >= 38]

print(dt_new)
# Out:
#                   country location_name  latitude  longitude         timezone  \
# 12                Bahrain        Manama     26.24      50.58     Asia/Bahrain
# 47               Djibouti      Djibouti     11.60      43.15  Africa/Djibouti
# 90                 Kuwait   Kuwait City     29.37      47.96      Asia/Kuwait
# 141                 Qatar          Doha     25.29      51.53       Asia/Qatar
# 151          Saudi Arabia        Riyadh     24.64      46.77      Asia/Riyadh
# 184  United Arab Emirates     Abu Dhabi     24.47      54.37       Asia/Dubai
#
#      last_updated_epoch      last_updated  temperature_celsius  \
# 12           1693301400  2023-08-29 12:30                 38.0
# 47           1693301400  2023-08-29 12:30                 42.0
# 90           1693301400  2023-08-29 12:30                 39.6
# 141          1693302300  2023-08-29 12:45                 38.0
# 151          1693301400  2023-08-29 12:30                 42.0
# ...

# %%
dt_new['humidity'].sum()
# Out:
# 176

# %%
dt_new['air_quality_Ozone'].mean()
# Out:
# 187.61666666666665

# %%
dt_new['longitude'].std()
# Out:
# 3.9494202106131975

# %%
dt_new['last_updated'].unique()
# Out:
# array(['2023-08-29 12:30', '2023-08-29 12:45', '2023-08-29 13:45'],
#       dtype=object)

# %%
dt_new.corr()
# Out:
# <ipython-input-25-761acf0126ce>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dt_new.corr()
#                               latitude  longitude  last_updated_epoch  \
# latitude                      1.000000   0.617804            0.161073
# longitude                     0.617804   1.000000            0.762943
# last_updated_epoch            0.161073   0.762943            1.000000
# temperature_celsius          -0.338511   0.048177            0.207050
# temperature_fahrenheit       -0.337866   0.047967            0.206598
# wind_mph                     -0.458576   0.114951            0.477671
# wind_kph                     -0.458437   0.120113            0.483694
# wind_degree                  -0.530293   0.027378            0.360862
# pressure_mb                  -0.770270  -0.823463           -0.489116
# ...
